# %%
# Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from itertools import combinations
from tqdm.notebook import tqdm
from sklearn.tree import plot_tree

# %%
# Datafile
df = pd.read_csv("./NA850data_2000-2014.csv")
df.head()
# Out:
#      AirTemp        QV     Omega  SeaLevPress     UWinds    VWinds         LH  \
# 0   7.060846  7.267001  0.000642  1021.565625 -11.894431 -5.276164  12.888080
# 1  10.865533  9.469151 -0.000444  1015.694375 -12.986907 -2.199314  16.006929
# 2   7.100183  7.474899 -0.000296  1021.084141 -11.230261 -3.172798 -10.217120
# 3  11.154810  9.294266  0.000126  1015.156875 -11.698672 -2.088208   1.020178
# 4   7.068231  7.335827  0.000323  1020.302969 -10.246526 -1.993664   0.511768
#
#          Lat        Lon  PtIndex  WaveTrajectory        Time
# 0  25.064459 -35.368896        0               1  2000010100
# 1  20.454613 -54.790527       18               1  2000010306
# 2  24.480576 -36.771637        1               1  2000010103
# 3  19.468901 -55.690735       19               1  2000010309
# 4  24.649042 -37.882874        2               1  2000010106

# %%
desc_corr = abs(df.corr('kendall'))[['LH']].sort_values(by='LH', ascending=False)
desc_corr
# Out:
#                       LH
# LH              1.000000
# Omega           0.487346
# QV              0.473145
# SeaLevPress     0.187259
# Lon             0.179262
# WaveTrajectory  0.134285
# Lat             0.133566
# AirTemp         0.131982
# Time            0.046707
# UWinds          0.038739
# VWinds          0.021704
# PtIndex         0.002943

# %%
LQ = df.LH.quantile(0.25)
UQ = df.LH.quantile(0.75)
bound = 1.5 * (UQ - LQ) #Whisker length * IQR
lower_bound = LQ - bound
upper_bound = UQ + bound
df["Extreme"] = np.where( (df["LH"] > upper_bound) | (df["LH"]  < lower_bound), 1, 0)

# %%
data_Y = df["Extreme"]
data_X = df.drop(["Extreme", "LH"], axis=1)

# %%
data_X
# Out:
#          AirTemp        QV     Omega  SeaLevPress     UWinds    VWinds  \
# 0       7.060846  7.267001  0.000642  1021.565625 -11.894431 -5.276164
# 1      10.865533  9.469151 -0.000444  1015.694375 -12.986907 -2.199314
# 2       7.100183  7.474899 -0.000296  1021.084141 -11.230261 -3.172798
# 3      11.154810  9.294266  0.000126  1015.156875 -11.698672 -2.088208
# 4       7.068231  7.335827  0.000323  1020.302969 -10.246526 -1.993664
# ...          ...       ...       ...          ...        ...       ...
# 20299  13.976068  9.267782  0.000962  1013.787969  -5.725973  1.024751
# 20300  13.713007  8.729606 -0.000825  1014.931094  -5.089421  3.418641
# 20301  14.085962  9.510149  0.000713  1014.133594  -3.518239  3.075252
# 20302  13.607874  9.221160 -0.000341  1012.970781  -2.101092  4.653747
# 20303  13.264062  8.831773 -0.001441  1013.443594  -1.757324  5.988960
#
#              Lat        Lon  PtIndex  WaveTrajectory        Time
# 0      25.064459 -35.368896        0               1  2000010100
# 1      20.454613 -54.790527       18               1  2000010306
# 2      24.480576 -36.771637        1               1  2000010103
# 3      19.468901 -55.690735       19               1  2000010309
# 4      24.649042 -37.882874        2               1  2000010106
# ...          ...        ...      ...             ...         ...
# 20299  23.499479 -48.751160       51             240  2014121321
# 20300  23.499500 -49.022491       52             240  2014121400
# 20301  23.383141 -49.258881       53             240  2014121403
# 20302  23.517527 -49.335236       54             240  2014121406
# 20303  23.940237 -49.347076       55             240  2014121409
#
# [20304 rows x 11 columns]

# %%
res_combined = []
for index in range(2, len(desc_corr)):
    X_train, X_test, y_train, y_test = train_test_split(data_X[desc_corr.index[1:index]], data_Y, test_size=0.25, random_state=738)
    dt = DecisionTreeClassifier()
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    res_combined.append(f1_score(y_test, y_pred))
res_combined
# Out:
# [0.5552353506243997,
#  0.5436543654365437,
#  0.5526802218114603,
#  0.550185873605948,
#  0.5706570657065706,
#  0.5719489981785063,
#  0.583180987202925,
#  0.6231617647058824,
#  0.5894346617238183,
#  0.6036036036036035]

# %%
combs = []
for x in range(2, len(desc_corr)):
    combs += [list(y) for y in combinations(desc_corr.index[1:], x)]

# %%
# Keys will be index from combs list, Values will be F1 score
res_comb = []
for index in range(len(combs)):
    X_train, X_test, y_train, y_test = train_test_split(data_X[combs[index]], data_Y, test_size=0.25, random_state=738)
    dt = DecisionTreeClassifier()
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    res_comb.append(f1_score(y_test, y_pred))

# %%
best_index = res_comb.index(max(res_comb))
print("Best F1 score of %f using\n%s" % (res_comb[best_index], str(combs[best_index])))
# Out:
# Best F1 score of 0.628205 using
# ['Omega', 'QV', 'Lon', 'WaveTrajectory', 'AirTemp', 'Time', 'VWinds']

# %%
# Keys will be index from combs list, Values will be F1 score
res_comb = []
for index in range(len(combs)):
    X_train, X_test, y_train, y_test = train_test_split(data_X[combs[index]], data_Y, test_size=0.25, random_state=738)
    dt = DecisionTreeClassifier(max_depth=10)
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    res_comb.append(f1_score(y_test, y_pred))

# %%
best_index = res_comb.index(max(res_comb))
print("Best F1 score of %f using\n%s" % (res_comb[best_index], str(combs[best_index])))
# Out:
# Best F1 score of 0.665350 using
# ['Omega', 'WaveTrajectory', 'Lat', 'AirTemp', 'Time', 'VWinds']

# %%
# Keys will be index from combs list, Values will be F1 score
res_comb = []
for index in range(len(combs)):
    X_train, X_test, y_train, y_test = train_test_split(data_X[combs[index]], data_Y, test_size=0.25, random_state=738)
    dt = DecisionTreeClassifier(criterion="entropy")
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    res_comb.append(f1_score(y_test, y_pred))

# %%
best_index = res_comb.index(max(res_comb))
print("Best F1 score of %f using\n%s" % (res_comb[best_index], str(combs[best_index])))
# Out:
# Best F1 score of 0.628263 using
# ['Omega', 'Lon', 'WaveTrajectory', 'Lat', 'AirTemp', 'UWinds', 'VWinds']

# %%
# Keys will be index from combs list, Values will be F1 score
res_comb = []
for index in range(len(combs)):
    X_train, X_test, y_train, y_test = train_test_split(data_X[combs[index]], data_Y, test_size=0.25, random_state=738)
    dt = DecisionTreeClassifier(criterion="entropy", max_depth=9)
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    res_comb.append(f1_score(y_test, y_pred))

# %%
best_index = res_comb.index(max(res_comb))
print("Best F1 score of %f using\n%s" % (res_comb[best_index], str(combs[best_index])))
# Out:
# Best F1 score of 0.669941 using
# ['Omega', 'Lat', 'AirTemp', 'Time']

# %%
X_train, X_test, y_train, y_test = train_test_split(data_X[combs[best_index]], data_Y, test_size=0.25, random_state=738)
dt = DecisionTreeClassifier(criterion="entropy", max_depth=9)
dt.fit(X_train, y_train)
# y_pred = dt.predict(X_test)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=9)

# %%
plot_tree(dt,filled = True, 
          rounded = True)
# Out:
# [Text(0.47650983146067416, 0.95, 'X[0] <= -0.003\nentropy = 0.477\nsamples = 15228\nvalue = [13665, 1563]'),
#  Text(0.2294943820224719, 0.85, 'X[0] <= -0.004\nentropy = 0.956\nsamples = 1817\nvalue = [685, 1132]'),
#  Text(0.08820224719101123, 0.75, 'X[0] <= -0.01\nentropy = 0.754\nsamples = 1144\nvalue = [248, 896]'),
#  Text(0.020224719101123594, 0.65, 'X[0] <= -0.014\nentropy = 0.31\nsamples = 378\nvalue = [21, 357]'),
#  Text(0.008988764044943821, 0.55, 'X[3] <= 2013090240.0\nentropy = 0.058\nsamples = 150\nvalue = [1, 149]'),
#  Text(0.0044943820224719105, 0.45, 'entropy = 0.0\nsamples = 121\nvalue = [0, 121]'),
#  Text(0.01348314606741573, 0.45, 'X[3] <= 2013095616.0\nentropy = 0.216\nsamples = 29\nvalue = [1, 28]'),
#  Text(0.008988764044943821, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.017977528089887642, 0.35, 'entropy = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.03146067415730337, 0.55, 'X[3] <= 2003070528.0\nentropy = 0.429\nsamples = 228\nvalue = [20, 208]'),
#  Text(0.02696629213483146, 0.45, 'entropy = 0.0\nsamples = 44\nvalue = [0, 44]'),
#  Text(0.035955056179775284, 0.45, 'X[3] <= 2005591040.0\nentropy = 0.496\nsamples = 184\nvalue = [20, 164]'),
#  Text(0.02696629213483146, 0.35, 'X[2] <= 15.349\nentropy = 0.85\nsamples = 29\nvalue = [8, 21]'),
#  Text(0.02247191011235955, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03146067415730337, 0.25, 'X[2] <= 18.099\nentropy = 0.764\nsamples = 27\nvalue = [6, 21]'),
#  Text(0.02696629213483146, 0.15, 'X[0] <= -0.011\nentropy = 0.634\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.02247191011235955, 0.05, 'entropy = 0.811\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.03146067415730337, 0.05, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.035955056179775284, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0449438202247191, 0.35, 'X[3] <= 2008061376.0\nentropy = 0.393\nsamples = 155\nvalue = [12, 143]'),
#  Text(0.04044943820224719, 0.25, 'entropy = 0.0\nsamples = 37\nvalue = [0, 37]'),
#  Text(0.04943820224719101, 0.25, 'X[3] <= 2013060928.0\nentropy = 0.474\nsamples = 118\nvalue = [12, 106]'),
#  Text(0.0449438202247191, 0.15, 'X[0] <= -0.013\nentropy = 0.544\nsamples = 96\nvalue = [12, 84]'),
#  Text(0.04044943820224719, 0.05, 'entropy = 0.874\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.04943820224719101, 0.05, 'entropy = 0.432\nsamples = 79\nvalue = [7, 72]'),
#  Text(0.05393258426966292, 0.15, 'entropy = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.15617977528089888, 0.65, 'X[0] <= -0.006\nentropy = 0.877\nsamples = 766\nvalue = [227, 539]'),
#  Text(0.1101123595505618, 0.55, 'X[2] <= 19.183\nentropy = 0.8\nsamples = 473\nvalue = [115, 358]'),
#  Text(0.10561797752808989, 0.45, 'X[3] <= 2010102464.0\nentropy = 0.789\nsamples = 469\nvalue = [111, 358]'),
#  Text(0.07640449438202247, 0.35, 'X[0] <= -0.007\nentropy = 0.736\nsamples = 348\nvalue = [72, 276]'),
#  Text(0.06741573033707865, 0.25, 'X[0] <= -0.008\nentropy = 0.629\nsamples = 190\nvalue = [30, 160]'),
#  Text(0.06292134831460675, 0.15, 'X[2] <= 16.567\nentropy = 0.696\nsamples = 160\nvalue = [30, 130]'),
#  Text(0.058426966292134834, 0.05, 'entropy = 0.216\nsamples = 29\nvalue = [1, 28]'),
#  Text(0.06741573033707865, 0.05, 'entropy = 0.763\nsamples = 131\nvalue = [29, 102]'),
#  Text(0.07191011235955057, 0.15, 'entropy = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.0853932584269663, 0.25, 'X[2] <= 15.58\nentropy = 0.835\nsamples = 158\nvalue = [42, 116]'),
#  Text(0.08089887640449438, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0898876404494382, 0.15, 'X[1] <= 10.231\nentropy = 0.814\nsamples = 155\nvalue = [39, 116]'),
#  Text(0.0853932584269663, 0.05, 'entropy = 0.656\nsamples = 65\nvalue = [11, 54]'),
#  Text(0.09438202247191012, 0.05, 'entropy = 0.894\nsamples = 90\nvalue = [28, 62]'),
#  Text(0.1348314606741573, 0.35, 'X[3] <= 2011070656.0\nentropy = 0.907\nsamples = 121\nvalue = [39, 82]'),
#  Text(0.11685393258426967, 0.25, 'X[3] <= 2011051712.0\nentropy = 0.988\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.10786516853932585, 0.15, 'X[1] <= 9.664\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.10337078651685393, 0.05, 'entropy = 0.684\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.11235955056179775, 0.05, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1258426966292135, 0.15, 'X[2] <= 16.742\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.12134831460674157, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1303370786516854, 0.05, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.15280898876404495, 0.25, 'X[3] <= 2012096640.0\nentropy = 0.835\nsamples = 98\nvalue = [26, 72]'),
#  Text(0.14382022471910114, 0.15, 'X[2] <= 17.445\nentropy = 0.513\nsamples = 35\nvalue = [4, 31]'),
#  Text(0.1393258426966292, 0.05, 'entropy = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.14831460674157304, 0.05, 'entropy = 0.787\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.16179775280898875, 0.15, 'X[3] <= 2013066880.0\nentropy = 0.933\nsamples = 63\nvalue = [22, 41]'),
#  Text(0.15730337078651685, 0.05, 'entropy = 0.971\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.1662921348314607, 0.05, 'entropy = 0.689\nsamples = 38\nvalue = [7, 31]'),
#  Text(0.1146067415730337, 0.45, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.20224719101123595, 0.55, 'X[0] <= -0.004\nentropy = 0.96\nsamples = 293\nvalue = [112, 181]'),
#  Text(0.19775280898876405, 0.45, 'X[2] <= 15.346\nentropy = 0.967\nsamples = 285\nvalue = [112, 173]'),
#  Text(0.1797752808988764, 0.35, 'X[2] <= 12.914\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.1752808988764045, 0.25, 'X[0] <= -0.005\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1707865168539326, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1797752808988764, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1842696629213483, 0.25, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.2157303370786517, 0.35, 'X[3] <= 2012080576.0\nentropy = 0.959\nsamples = 278\nvalue = [106, 172]'),
#  Text(0.19775280898876405, 0.25, 'X[0] <= -0.005\nentropy = 0.933\nsamples = 235\nvalue = [82, 153]'),
#  Text(0.18876404494382024, 0.15, 'X[0] <= -0.005\nentropy = 0.978\nsamples = 121\nvalue = [50, 71]'),
#  Text(0.1842696629213483, 0.05, 'entropy = 0.967\nsamples = 117\nvalue = [46, 71]'),
#  Text(0.19325842696629214, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.20674157303370785, 0.15, 'X[2] <= 18.394\nentropy = 0.856\nsamples = 114\nvalue = [32, 82]'),
#  Text(0.20224719101123595, 0.05, 'entropy = 0.887\nsamples = 105\nvalue = [32, 73]'),
#  Text(0.21123595505617979, 0.05, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.23370786516853934, 0.25, 'X[2] <= 16.879\nentropy = 0.99\nsamples = 43\nvalue = [24, 19]'),
#  Text(0.2247191011235955, 0.15, 'X[3] <= 2013571072.0\nentropy = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.2202247191011236, 0.05, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.2292134831460674, 0.05, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.24269662921348314, 0.15, 'X[3] <= 2012082624.0\nentropy = 0.978\nsamples = 29\nvalue = [12, 17]'),
#  Text(0.23820224719101124, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.24719101123595505, 0.05, 'entropy = 0.904\nsamples = 25\nvalue = [8, 17]'),
#  Text(0.20674157303370785, 0.45, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.3707865168539326, 0.75, 'X[0] <= -0.004\nentropy = 0.935\nsamples = 673\nvalue = [437, 236]'),
#  Text(0.32808988764044944, 0.65, 'X[3] <= 2011102208.0\nentropy = 0.993\nsamples = 239\nvalue = [131, 108]'),
#  Text(0.30112359550561796, 0.55, 'X[3] <= 2011070528.0\nentropy = 1.0\nsamples = 188\nvalue = [93, 95]'),
#  Text(0.2966292134831461, 0.45, 'X[3] <= 2004096640.0\nentropy = 0.999\nsamples = 180\nvalue = [93, 87]'),
#  Text(0.27415730337078653, 0.35, 'X[1] <= 12.015\nentropy = 0.963\nsamples = 75\nvalue = [46, 29]'),
#  Text(0.2651685393258427, 0.25, 'X[0] <= -0.004\nentropy = 1.0\nsamples = 51\nvalue = [25, 26]'),
#  Text(0.2606741573033708, 0.15, 'X[3] <= 2001062592.0\nentropy = 0.991\nsamples = 45\nvalue = [25, 20]'),
#  Text(0.25617977528089886, 0.05, 'entropy = 0.779\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.2651685393258427, 0.05, 'entropy = 0.896\nsamples = 32\nvalue = [22, 10]'),
#  Text(0.2696629213483146, 0.15, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.28314606741573034, 0.25, 'X[3] <= 2001591552.0\nentropy = 0.544\nsamples = 24\nvalue = [21, 3]'),
#  Text(0.2786516853932584, 0.15, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.2876404494382023, 0.15, 'X[3] <= 2002580480.0\nentropy = 0.811\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.28314606741573034, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29213483146067415, 0.05, 'entropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.31910112359550563, 0.35, 'X[2] <= 18.143\nentropy = 0.992\nsamples = 105\nvalue = [47, 58]'),
#  Text(0.3101123595505618, 0.25, 'X[2] <= 17.982\nentropy = 0.999\nsamples = 95\nvalue = [46, 49]'),
#  Text(0.3056179775280899, 0.15, 'X[2] <= 15.625\nentropy = 0.994\nsamples = 90\nvalue = [41, 49]'),
#  Text(0.30112359550561796, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3101123595505618, 0.05, 'entropy = 0.998\nsamples = 86\nvalue = [41, 45]'),
#  Text(0.3146067415730337, 0.15, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.32808988764044944, 0.25, 'X[3] <= 2009095808.0\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.3235955056179775, 0.15, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.3325842696629214, 0.15, 'X[0] <= -0.004\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.32808988764044944, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.33707865168539325, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3056179775280899, 0.45, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.3550561797752809, 0.55, 'X[1] <= 7.763\nentropy = 0.819\nsamples = 51\nvalue = [38, 13]'),
#  Text(0.34606741573033706, 0.45, 'X[1] <= 7.574\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.3415730337078652, 0.35, 'X[1] <= 6.187\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.33707865168539325, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34606741573033706, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.350561797752809, 0.35, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.36404494382022473, 0.45, 'X[0] <= -0.004\nentropy = 0.731\nsamples = 44\nvalue = [35, 9]'),
#  Text(0.3595505617977528, 0.35, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3685393258426966, 0.35, 'X[3] <= 2012072960.0\nentropy = 0.845\nsamples = 33\nvalue = [24, 9]'),
#  Text(0.36404494382022473, 0.25, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.37303370786516854, 0.25, 'X[0] <= -0.004\nentropy = 0.918\nsamples = 27\nvalue = [18, 9]'),
#  Text(0.36404494382022473, 0.15, 'X[0] <= -0.004\nentropy = 0.997\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.3595505617977528, 0.05, 'entropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.3685393258426966, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.38202247191011235, 0.15, 'X[0] <= -0.004\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.3775280898876405, 0.05, 'entropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.3865168539325843, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4134831460674157, 0.65, 'X[0] <= -0.004\nentropy = 0.875\nsamples = 434\nvalue = [306, 128]'),
#  Text(0.40898876404494383, 0.55, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.41797752808988764, 0.55, 'X[1] <= 6.121\nentropy = 0.889\nsamples = 418\nvalue = [290, 128]'),
#  Text(0.3955056179775281, 0.45, 'X[3] <= 2008056320.0\nentropy = 0.402\nsamples = 25\nvalue = [23, 2]'),
#  Text(0.39101123595505616, 0.35, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.4, 0.35, 'X[1] <= 5.324\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.3955056179775281, 0.25, 'X[2] <= 17.522\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.39101123595505616, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4044943820224719, 0.25, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4404494382022472, 0.45, 'X[1] <= 15.338\nentropy = 0.905\nsamples = 393\nvalue = [267, 126]'),
#  Text(0.41797752808988764, 0.35, 'X[3] <= 2000061184.0\nentropy = 0.874\nsamples = 326\nvalue = [230, 96]'),
#  Text(0.4134831460674157, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.42247191011235957, 0.25, 'X[3] <= 2012586304.0\nentropy = 0.863\nsamples = 322\nvalue = [230, 92]'),
#  Text(0.4134831460674157, 0.15, 'X[3] <= 2007097024.0\nentropy = 0.89\nsamples = 290\nvalue = [201, 89]'),
#  Text(0.40898876404494383, 0.05, 'entropy = 0.763\nsamples = 158\nvalue = [123, 35]'),
#  Text(0.41797752808988764, 0.05, 'entropy = 0.976\nsamples = 132\nvalue = [78, 54]'),
#  Text(0.4314606741573034, 0.15, 'X[3] <= 2013095680.0\nentropy = 0.449\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.42696629213483145, 0.05, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.43595505617977526, 0.05, 'entropy = 0.65\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.46292134831460674, 0.35, 'X[0] <= -0.003\nentropy = 0.992\nsamples = 67\nvalue = [37, 30]'),
#  Text(0.4584269662921348, 0.25, 'X[1] <= 21.06\nentropy = 0.978\nsamples = 63\nvalue = [37, 26]'),
#  Text(0.449438202247191, 0.15, 'X[0] <= -0.003\nentropy = 0.999\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.4449438202247191, 0.05, 'entropy = 0.999\nsamples = 46\nvalue = [22, 24]'),
#  Text(0.45393258426966293, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.46741573033707867, 0.15, 'X[1] <= 23.611\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.46292134831460674, 0.05, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.47191011235955055, 0.05, 'entropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.46741573033707867, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7235252808988764, 0.85, 'X[0] <= -0.001\nentropy = 0.205\nsamples = 13411\nvalue = [12980, 431]'),
#  Text(0.5724719101123595, 0.75, 'X[0] <= -0.002\nentropy = 0.465\nsamples = 2197\nvalue = [1980, 217]'),
#  Text(0.5179775280898876, 0.65, 'X[2] <= 15.415\nentropy = 0.62\nsamples = 838\nvalue = [709, 129]'),
#  Text(0.4966292134831461, 0.55, 'X[3] <= 2007120576.0\nentropy = 0.961\nsamples = 39\nvalue = [24, 15]'),
#  Text(0.4853932584269663, 0.45, 'X[0] <= -0.002\nentropy = 0.523\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.48089887640449436, 0.35, 'X[2] <= 14.413\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4764044943820225, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4853932584269663, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4898876404494382, 0.35, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.5078651685393258, 0.45, 'X[0] <= -0.002\nentropy = 0.976\nsamples = 22\nvalue = [9, 13]'),
#  Text(0.503370786516854, 0.35, 'X[1] <= 21.131\nentropy = 0.9\nsamples = 19\nvalue = [6, 13]'),
#  Text(0.4943820224719101, 0.25, 'X[0] <= -0.003\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.4898876404494382, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.49887640449438203, 0.15, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5123595505617977, 0.25, 'X[0] <= -0.002\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.5078651685393258, 0.15, 'X[3] <= 2011097344.0\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.503370786516854, 0.05, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5123595505617977, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5168539325842697, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5123595505617977, 0.35, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5393258426966292, 0.55, 'X[3] <= 2014066624.0\nentropy = 0.591\nsamples = 799\nvalue = [685, 114]'),
#  Text(0.5303370786516854, 0.45, 'X[0] <= -0.002\nentropy = 0.609\nsamples = 755\nvalue = [642, 113]'),
#  Text(0.5258426966292135, 0.35, 'X[0] <= -0.003\nentropy = 0.603\nsamples = 753\nvalue = [642, 111]'),
#  Text(0.5213483146067416, 0.25, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.5303370786516854, 0.25, 'X[2] <= 20.009\nentropy = 0.612\nsamples = 735\nvalue = [624, 111]'),
#  Text(0.5258426966292135, 0.15, 'X[2] <= 17.651\nentropy = 0.621\nsamples = 718\nvalue = [607, 111]'),
#  Text(0.5213483146067416, 0.05, 'entropy = 0.574\nsamples = 559\nvalue = [483, 76]'),
#  Text(0.5303370786516854, 0.05, 'entropy = 0.76\nsamples = 159\nvalue = [124, 35]'),
#  Text(0.5348314606741573, 0.15, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.5348314606741573, 0.35, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5483146067415731, 0.45, 'X[1] <= 15.83\nentropy = 0.156\nsamples = 44\nvalue = [43, 1]'),
#  Text(0.5438202247191011, 0.35, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(0.5528089887640449, 0.35, 'X[2] <= 17.51\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5483146067415731, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5573033707865168, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6269662921348315, 0.65, 'X[2] <= 14.368\nentropy = 0.346\nsamples = 1359\nvalue = [1271, 88]'),
#  Text(0.5865168539325842, 0.55, 'X[3] <= 2009011392.0\nentropy = 0.84\nsamples = 52\nvalue = [38, 14]'),
#  Text(0.5662921348314607, 0.45, 'X[3] <= 2000021184.0\nentropy = 0.439\nsamples = 33\nvalue = [30, 3]'),
#  Text(0.5617977528089888, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5707865168539326, 0.35, 'X[1] <= 23.431\nentropy = 0.337\nsamples = 32\nvalue = [30, 2]'),
#  Text(0.5662921348314607, 0.25, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.5752808988764045, 0.25, 'X[1] <= 24.056\nentropy = 0.567\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.5707865168539326, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5797752808988764, 0.15, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.6067415730337079, 0.45, 'X[0] <= -0.001\nentropy = 0.982\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.597752808988764, 0.35, 'X[2] <= 12.293\nentropy = 0.811\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.5932584269662922, 0.25, 'X[0] <= -0.002\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.5887640449438202, 0.15, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.597752808988764, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6022471910112359, 0.25, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6157303370786517, 0.35, 'X[0] <= -0.001\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.6112359550561798, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6202247191011236, 0.25, 'X[1] <= 19.097\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6157303370786517, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6247191011235955, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6674157303370787, 0.55, 'X[2] <= 19.128\nentropy = 0.314\nsamples = 1307\nvalue = [1233, 74]'),
#  Text(0.6629213483146067, 0.45, 'X[3] <= 2014086528.0\nentropy = 0.33\nsamples = 1218\nvalue = [1144, 74]'),
#  Text(0.6584269662921348, 0.35, 'X[0] <= -0.001\nentropy = 0.341\nsamples = 1165\nvalue = [1091, 74]'),
#  Text(0.6426966292134831, 0.25, 'X[3] <= 2013071680.0\nentropy = 0.329\nsamples = 1142\nvalue = [1073, 69]'),
#  Text(0.6337078651685393, 0.15, 'X[3] <= 2011082816.0\nentropy = 0.305\nsamples = 1045\nvalue = [988, 57]'),
#  Text(0.6292134831460674, 0.05, 'entropy = 0.331\nsamples = 905\nvalue = [850, 55]'),
#  Text(0.6382022471910113, 0.05, 'entropy = 0.108\nsamples = 140\nvalue = [138, 2]'),
#  Text(0.651685393258427, 0.15, 'X[3] <= 2013080512.0\nentropy = 0.54\nsamples = 97\nvalue = [85, 12]'),
#  Text(0.647191011235955, 0.05, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6561797752808989, 0.05, 'entropy = 0.459\nsamples = 93\nvalue = [84, 9]'),
#  Text(0.6741573033707865, 0.25, 'X[3] <= 2008560960.0\nentropy = 0.755\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.6696629213483146, 0.15, 'X[2] <= 17.618\nentropy = 0.918\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.6651685393258427, 0.05, 'entropy = 0.722\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.6741573033707865, 0.05, 'entropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.6786516853932584, 0.15, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6674157303370787, 0.35, 'entropy = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.6719101123595506, 0.45, 'entropy = 0.0\nsamples = 89\nvalue = [89, 0]'),
#  Text(0.8745786516853933, 0.75, 'X[0] <= 0.002\nentropy = 0.136\nsamples = 11214\nvalue = [11000, 214]'),
#  Text(0.8266853932584269, 0.65, 'X[2] <= 18.702\nentropy = 0.115\nsamples = 11079\nvalue = [10908, 171]'),
#  Text(0.7792134831460674, 0.55, 'X[2] <= 13.769\nentropy = 0.138\nsamples = 8768\nvalue = [8598, 170]'),
#  Text(0.7258426966292135, 0.45, 'X[2] <= 7.808\nentropy = 0.292\nsamples = 1052\nvalue = [998, 54]'),
#  Text(0.701123595505618, 0.35, 'X[0] <= 0.001\nentropy = 0.849\nsamples = 40\nvalue = [29, 11]'),
#  Text(0.6966292134831461, 0.25, 'X[3] <= 2012022208.0\nentropy = 0.958\nsamples = 29\nvalue = [18, 11]'),
#  Text(0.6876404494382022, 0.15, 'X[3] <= 2004016832.0\nentropy = 0.773\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.6831460674157304, 0.05, 'entropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.6921348314606741, 0.05, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7056179775280899, 0.15, 'X[2] <= 7.553\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.701123595505618, 0.05, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7101123595505618, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7056179775280899, 0.25, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.750561797752809, 0.35, 'X[0] <= -0.0\nentropy = 0.254\nsamples = 1012\nvalue = [969, 43]'),
#  Text(0.7325842696629213, 0.25, 'X[3] <= 2005096576.0\nentropy = 0.471\nsamples = 258\nvalue = [232, 26]'),
#  Text(0.7235955056179775, 0.15, 'X[0] <= -0.0\nentropy = 0.283\nsamples = 122\nvalue = [116, 6]'),
#  Text(0.7191011235955056, 0.05, 'entropy = 0.214\nsamples = 118\nvalue = [114, 4]'),
#  Text(0.7280898876404495, 0.05, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7415730337078652, 0.15, 'X[3] <= 2005591744.0\nentropy = 0.602\nsamples = 136\nvalue = [116, 20]'),
#  Text(0.7370786516853932, 0.05, 'entropy = 0.954\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.7460674157303371, 0.05, 'entropy = 0.521\nsamples = 128\nvalue = [113, 15]'),
#  Text(0.7685393258426966, 0.25, 'X[1] <= 21.844\nentropy = 0.156\nsamples = 754\nvalue = [737, 17]'),
#  Text(0.7595505617977528, 0.15, 'X[1] <= 20.084\nentropy = 0.24\nsamples = 404\nvalue = [388, 16]'),
#  Text(0.755056179775281, 0.05, 'entropy = 0.111\nsamples = 271\nvalue = [267, 4]'),
#  Text(0.7640449438202247, 0.05, 'entropy = 0.437\nsamples = 133\nvalue = [121, 12]'),
#  Text(0.7775280898876404, 0.15, 'X[2] <= 9.658\nentropy = 0.028\nsamples = 350\nvalue = [349, 1]'),
#  Text(0.7730337078651686, 0.05, 'entropy = 0.169\nsamples = 40\nvalue = [39, 1]'),
#  Text(0.7820224719101123, 0.05, 'entropy = 0.0\nsamples = 310\nvalue = [310, 0]'),
#  Text(0.8325842696629213, 0.45, 'X[0] <= -0.0\nentropy = 0.113\nsamples = 7716\nvalue = [7600, 116]'),
#  Text(0.8089887640449438, 0.35, 'X[0] <= -0.0\nentropy = 0.169\nsamples = 3151\nvalue = [3072, 79]'),
#  Text(0.8044943820224719, 0.25, 'X[0] <= -0.001\nentropy = 0.166\nsamples = 3149\nvalue = [3072, 77]'),
#  Text(0.7955056179775281, 0.15, 'X[3] <= 2006061888.0\nentropy = 0.248\nsamples = 919\nvalue = [881, 38]'),
#  Text(0.7910112359550562, 0.05, 'entropy = 0.108\nsamples = 351\nvalue = [346, 5]'),
#  Text(0.8, 0.05, 'entropy = 0.32\nsamples = 568\nvalue = [535, 33]'),
#  Text(0.8134831460674158, 0.15, 'X[1] <= 5.226\nentropy = 0.127\nsamples = 2230\nvalue = [2191, 39]'),
#  Text(0.8089887640449438, 0.05, 'entropy = 0.592\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.8179775280898877, 0.05, 'entropy = 0.118\nsamples = 2202\nvalue = [2167, 35]'),
#  Text(0.8134831460674158, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8561797752808988, 0.35, 'X[1] <= 10.83\nentropy = 0.068\nsamples = 4565\nvalue = [4528, 37]'),
#  Text(0.8404494382022472, 0.25, 'X[0] <= 0.002\nentropy = 0.134\nsamples = 1119\nvalue = [1098, 21]'),
#  Text(0.8314606741573034, 0.15, 'X[1] <= 10.828\nentropy = 0.113\nsamples = 1063\nvalue = [1047, 16]'),
#  Text(0.8269662921348314, 0.05, 'entropy = 0.107\nsamples = 1062\nvalue = [1047, 15]'),
#  Text(0.8359550561797753, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.849438202247191, 0.15, 'X[3] <= 2006061952.0\nentropy = 0.434\nsamples = 56\nvalue = [51, 5]'),
#  Text(0.8449438202247191, 0.05, 'entropy = 0.663\nsamples = 29\nvalue = [24, 5]'),
#  Text(0.8539325842696629, 0.05, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.8719101123595505, 0.25, 'X[2] <= 18.702\nentropy = 0.043\nsamples = 3446\nvalue = [3430, 16]'),
#  Text(0.8674157303370786, 0.15, 'X[3] <= 2011121600.0\nentropy = 0.04\nsamples = 3445\nvalue = [3430, 15]'),
#  Text(0.8629213483146068, 0.05, 'entropy = 0.048\nsamples = 2828\nvalue = [2813, 15]'),
#  Text(0.8719101123595505, 0.05, 'entropy = 0.0\nsamples = 617\nvalue = [617, 0]'),
#  Text(0.8764044943820225, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8741573033707866, 0.55, 'X[0] <= -0.001\nentropy = 0.005\nsamples = 2311\nvalue = [2310, 1]'),
#  Text(0.8696629213483146, 0.45, 'X[1] <= 12.6\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.8651685393258427, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8741573033707866, 0.35, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8786516853932584, 0.45, 'entropy = 0.0\nsamples = 2303\nvalue = [2303, 0]'),
#  Text(0.9224719101123595, 0.65, 'X[0] <= 0.003\nentropy = 0.903\nsamples = 135\nvalue = [92, 43]'),
#  Text(0.8921348314606742, 0.55, 'X[0] <= 0.002\nentropy = 0.592\nsamples = 63\nvalue = [54, 9]'),
#  Text(0.8876404494382022, 0.45, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8966292134831461, 0.45, 'X[0] <= 0.003\nentropy = 0.514\nsamples = 61\nvalue = [54, 7]'),
#  Text(0.8921348314606742, 0.35, 'X[2] <= 15.391\nentropy = 0.65\nsamples = 42\nvalue = [35, 7]'),
#  Text(0.8876404494382022, 0.25, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.8966292134831461, 0.25, 'X[2] <= 17.944\nentropy = 0.758\nsamples = 32\nvalue = [25, 7]'),
#  Text(0.8921348314606742, 0.15, 'X[1] <= 8.391\nentropy = 0.871\nsamples = 24\nvalue = [17, 7]'),
#  Text(0.8876404494382022, 0.05, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8966292134831461, 0.05, 'entropy = 0.964\nsamples = 18\nvalue = [11, 7]'),
#  Text(0.9011235955056179, 0.15, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9011235955056179, 0.35, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.952808988764045, 0.55, 'X[2] <= 17.317\nentropy = 0.998\nsamples = 72\nvalue = [38, 34]'),
#  Text(0.9325842696629213, 0.45, 'X[2] <= 16.969\nentropy = 0.949\nsamples = 38\nvalue = [14, 24]'),
#  Text(0.9280898876404494, 0.35, 'X[2] <= 16.289\nentropy = 1.0\nsamples = 28\nvalue = [14, 14]'),
#  Text(0.9146067415730337, 0.25, 'X[0] <= 0.003\nentropy = 0.811\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.9101123595505618, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9191011235955057, 0.15, 'X[0] <= 0.005\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.9146067415730337, 0.05, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9235955056179775, 0.05, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9415730337078652, 0.25, 'X[2] <= 16.909\nentropy = 0.896\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.9370786516853933, 0.15, 'X[1] <= 8.984\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.9325842696629213, 0.05, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9415730337078652, 0.05, 'entropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.946067415730337, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9370786516853933, 0.35, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.9730337078651685, 0.45, 'X[1] <= 10.826\nentropy = 0.874\nsamples = 34\nvalue = [24, 10]'),
#  Text(0.9640449438202248, 0.35, 'X[1] <= 6.157\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.9595505617977528, 0.25, 'X[2] <= 17.456\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9550561797752809, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9640449438202248, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9685393258426966, 0.25, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.9820224719101124, 0.35, 'X[2] <= 17.463\nentropy = 1.0\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.9775280898876404, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9865168539325843, 0.25, 'X[0] <= 0.003\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.9820224719101124, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9910112359550561, 0.15, 'X[1] <= 11.154\nentropy = 1.0\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.9865168539325843, 0.05, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9955056179775281, 0.05, 'entropy = 0.996\nsamples = 13\nvalue = [7, 6]')]
